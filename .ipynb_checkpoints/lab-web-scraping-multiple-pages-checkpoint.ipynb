# %%
import pandas as pd

# %%
hot = pd.read_csv('..\\lab-web-scraping-single-page\\song_artist.csv')
hot
# Out:
#                          artist                 song
# 0                  harry styles            as it was
# 1                   jack harlow          first class
# 2                     cat burns                   go
# 3                 aitch/ashanti                 baby
# 4                          dave            starlight
# ..                          ...                  ...
# 95                      wet leg        chaise longue
# 96                       eminem  the real slim shady
# 97  pusha t/kanye west/kid cudi          rock n roll
# 98            dave ft burna boy             location
# 99                lewis capaldi    someone you loved
#
# [100 rows x 2 columns]

# %%
# hot_songs = hot.drop("artist", axis = 1).values.tolist()
# hot_songs

hot['song'].values.tolist()
# Out:
# ['as it was',
#  'first class',
#  'go',
#  'baby',
#  'starlight',
#  'peru',
#  'bmw',
#  'bam bam',
#  'where did you go',
#  'make me feel good',
#  'down under',
#  'gangsteritus',
#  '2step',
#  'house on fire',
#  'anyone for you',
#  "she's all i wanna be",
#  'flowers',
#  'crazy what love can do',
#  'night away (dance)',
#  'the motto',
#  'thousand miles',
#  'bad habits',
#  'where are you now',
#  'one of a kind music pts reggae & calypso',
#  'what would you do',
#  'heat waves',
#  'light switch',
#  'run',
#  'shivers',
#  '10 things i hate about you',
#  'birthday cake',
#  'seventeen going under',
#  'big energy',
#  'glad u came',
#  'balling',
#  'melody',
#  'freaky deaky',
#  'do it to it',
#  'numb little bug',
#  'cold heart',
#  "don't forget my love",
#  'used to this',
#  'middle of the night',
#  "we don't talk about bruno",
#  'dandelions',
#  'green green grass',
#  'remind me',
#  'in my head',
#  'still sleepless',
#  'all for you',
#  'abcdefu',
# ...

# %%
songchoice = input('enter a song name ')
# hot_songs = hot['song'].values.tolist() not a good idea as recommendation can return the same input song

if songchoice.lower() in list(hot['song']):
    print("We recommend this hot song:")
    display(hot.sample())
else:
    print("no recommendation at this time. Input another song")
# Out:
# enter a song name iris
# We recommend this hot song:
#             artist     song
# 34  vibe chemistry  balling
